# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
df1=pd.read_csv(r"C:\Users\alaap\Downloads\iris.csv")

# %% [markdown]
# # 2.Display the columns in the dataset

# %%
df1.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
SL_MEAN=df1['SL'].mean()# 2. 
SW_MEAN=df1['SW'].mean()
PL_MEAN=df1['PL'].mean()
PW_MEAN=df1['PW'].mean()

# %%
SL_MEAN=round(SL_MEAN,2)
SW_MEAN=round(SW_MEAN,2)
PL_MEAN=round(PL_MEAN,2)
PW_MEAN=round(PW_MEAN,2)

# %%
print('mean of SL,SW,PL,PW',SL_MEAN,SW_MEAN,PL_MEAN,PW_MEAN)
# Out:
# mean of SL,SW,PL,PW 5.84 3.05 3.76 1.2

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
pd.isna(df1)
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
pd.isna(df1).sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations

# %%
plt.plot(df1['SL'],df1['SW'])
plt.show()

# %%
plt.plot(df1['SW'],df1['Classification'])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 8))

for x, ax in zip(df1.iloc[:, :4], axes.flatten()):
    sns.histplot(df1[x], ax=ax)
    ax.set_title('Distribution of {}'.format(x))
